# %% [markdown]
# # 데이터 취득 및 정제
#
# ## 데이터 취득

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### github의 raw 파일 획득, url을 복사하여 활용

# %%
df =  pd.read_csv('https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/5eb703da22102863ec6ee96927ee6b0042b28c6d/Iris.csv', index_col='Id')

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# 6              5.4           3.9            1.7           0.4     Iris-setosa
# 7              4.6           3.4            1.4           0.3     Iris-setosa
# 8              5.0           3.4            1.5           0.2     Iris-setosa
# 9              4.4           2.9            1.4           0.2     Iris-setosa
# 10             4.9           3.1            1.5           0.1     Iris-setosa
# 11             5.4           3.7            1.5           0.2     Iris-setosa
# ...

# %%
df.dtypes
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.name = 'iris'

# %%
df.dtypes
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.4+ KB

# %%
df[df.SepalLengthCm > 5.0]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# Id
# 1              5.1           3.5            1.4           0.2      Iris-setosa
# 6              5.4           3.9            1.7           0.4      Iris-setosa
# 11             5.4           3.7            1.5           0.2      Iris-setosa
# 15             5.8           4.0            1.2           0.2      Iris-setosa
# 16             5.7           4.4            1.5           0.4      Iris-setosa
# 17             5.4           3.9            1.3           0.4      Iris-setosa
# 18             5.1           3.5            1.4           0.3      Iris-setosa
# 19             5.7           3.8            1.7           0.3      Iris-setosa
# 20             5.1           3.8            1.5           0.3      Iris-setosa
# 21             5.4           3.4            1.7           0.2      Iris-setosa
# 22             5.1           3.7            1.5           0.4      Iris-setosa
# ...

# %%
df[df.SepalLengthCm > 5.0].shape
# Out:
# (118, 5)

# %%
setosa = df[df.Species == 'Iris-setosa']
print(setosa.PetalLengthCm)
print(setosa.shape)
# Out:
# Id
# 1     1.4
# 2     1.4
# 3     1.3
# 4     1.5
# 5     1.4
# 6     1.7
# 7     1.4
# 8     1.5
# 9     1.4
# 10    1.5
# 11    1.5
# 12    1.6
# 13    1.4
# 14    1.1
# 15    1.2
# 16    1.5
# 17    1.3
# 18    1.4
# 19    1.7
# 20    1.5
# 21    1.7
# 22    1.5
# 23    1.0
# 24    1.7
# 25    1.9
# 26    1.6
# 27    1.6
# 28    1.5
# 29    1.4
# 30    1.6
# 31    1.6
# 32    1.5
# 33    1.5
# 34    1.4
# 35    1.5
# 36    1.2
# 37    1.3
# 38    1.5
# 39    1.3
# 40    1.5
# 41    1.3
# 42    1.3
# 43    1.3
# 44    1.6
# 45    1.9
# 46    1.4
# 47    1.6
# 48    1.4
# 49    1.5
# 50    1.4
# Name: PetalLengthCm, dtype: float64
# (50, 5)

# %%
hflights_df = pd.read_csv('https://raw.githubusercontent.com/santiago02/hflights/master/hflights.csv')

# %%
hflights_df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 0  2011      1           1          6   1400.0   1500.0            AA
# 1  2011      1           2          7   1401.0   1501.0            AA
# 2  2011      1           3          1   1352.0   1502.0            AA
# 3  2011      1           4          2   1403.0   1513.0            AA
# 4  2011      1           5          3   1405.0   1507.0            AA
#
#    FlightNum TailNum  ActualElapsedTime   ...     ArrDelay  DepDelay  Origin  \
# 0        428  N576AA               60.0   ...        -10.0       0.0     IAH
# 1        428  N557AA               60.0   ...         -9.0       1.0     IAH
# 2        428  N541AA               70.0   ...         -8.0      -8.0     IAH
# 3        428  N403AA               70.0   ...          3.0       3.0     IAH
# 4        428  N492AA               62.0   ...         -3.0       5.0     IAH
#
#   Dest Distance  TaxiIn  TaxiOut  Cancelled  CancellationCode Diverted
# ...

# %%
hflights_df.tail()
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 227491  2011     12           6          2   1818.0   2111.0            WN
# 227492  2011     12           6          2   2047.0   2334.0            WN
# 227493  2011     12           6          2    912.0   1031.0            WN
# 227494  2011     12           6          2    656.0    812.0            WN
# 227495  2011     12           6          2   1600.0   1713.0            WN
#
#         FlightNum TailNum  ActualElapsedTime   ...     ArrDelay  DepDelay  \
# 227491       1191  N284WN              113.0   ...         -9.0       8.0
# 227492       1674  N366SW              107.0   ...          4.0       7.0
# 227493        127  N777QC               79.0   ...         -4.0      -3.0
# 227494        621  N727SW               76.0   ...        -13.0      -4.0
# 227495       1597  N745SW               73.0   ...        -12.0       0.0
#
# ...

# %%
hflights_df.shape
# Out:
# (227496, 21)

# %%
hflights_df.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'ArrTime',
#        'UniqueCarrier', 'FlightNum', 'TailNum', 'ActualElapsedTime', 'AirTime',
#        'ArrDelay', 'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn',
#        'TaxiOut', 'Cancelled', 'CancellationCode', 'Diverted'],
#       dtype='object')

# %%
hflights_df.isna() == True
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime  UniqueCarrier  \
# 0       False  False       False      False    False    False          False
# 1       False  False       False      False    False    False          False
# 2       False  False       False      False    False    False          False
# 3       False  False       False      False    False    False          False
# 4       False  False       False      False    False    False          False
# 5       False  False       False      False    False    False          False
# 6       False  False       False      False    False    False          False
# 7       False  False       False      False    False    False          False
# 8       False  False       False      False    False    False          False
# 9       False  False       False      False    False    False          False
# 10      False  False       False      False    False    False          False
# ...

# %%
hflights_df.CancellationCode
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16        NaN
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25        NaN
# 26        NaN
# 27        NaN
# 28        NaN
# 29        NaN
#          ...
# 227466    NaN
# 227467    NaN
# 227468    NaN
# 227469    NaN
# 227470    NaN
# 227471    NaN
# 227472    NaN
# 227473    NaN
# 227474    NaN
# 227475    NaN
# 227476    NaN
# 227477    NaN
# 227478    NaN
# 227479    NaN
# 227480    NaN
# 227481    NaN
# 227482    NaN
# 227483    NaN
# 227484    NaN
# 227485    NaN
# 227486    NaN
# 227487    NaN
# 227488    NaN
# 227489    NaN
# 227490    NaN
# 227491    NaN
# 227492    NaN
# 227493    NaN
# 227494    NaN
# 227495    NaN
# ...

# %%
hflights_df.ActualElapsedTime.max()
# Out:
# 575.0

# %%
hflights_df[hflights_df.ActualElapsedTime==575.0]
# Out:
#        Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime UniqueCarrier  \
# 23331  2011      2           7          1    942.0   1517.0            CO
#
#        FlightNum TailNum  ActualElapsedTime   ...     ArrDelay  DepDelay  \
# 23331          1  N77066              575.0   ...         87.0      17.0
#
#        Origin Dest Distance  TaxiIn  TaxiOut  Cancelled  CancellationCode  \
# 23331     IAH  HNL     3904     5.0     21.0          0               NaN
#
#       Diverted
# 23331        0
#
# [1 rows x 21 columns]

# %%
hflights_df[hflights_df.ActualElapsedTime==575][['UniqueCarrier', 'TailNum']]
# Out:
#       UniqueCarrier TailNum
# 23331            CO  N77066
