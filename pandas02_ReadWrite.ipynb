# %% [markdown]
# # 표 데이터를 일거나 쓰는 방법
#
#
# ### titanic 데이터 구조
# PassengerId: Id of every passenger.
#
# Survived: This feature have value 0 and 1. 0 for not survived and 1 for survived.
#
# Pclass: There are 3 classes: Class 1, Class 2 and Class 3.
#
# Name: Name of passenger.
#
# Sex: Gender of passenger.
#
# Age: Age of passenger.
#
# SibSp: Indication that passenger have siblings and spouse.
#
# Parch: Whether a passenger is alone or have family.
#
# Ticket: Ticket number of passenger.
#
# Fare: Indicating the fare.
#
# Cabin: The cabin of passenger.
#
# Embarked: The embarked category.

# %%
import pandas as pd
titanic = pd.read_csv('https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv', index_col=0)

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
titanic.head(10) ## 데이터프레임의 일부만 조회
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# ...

# %%
titanic.tail(10)
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 882                 0       3                        Markun, Mr. Johann
# 883                 0       3              Dahlberg, Miss. Gerda Ulrika
# 884                 0       2             Banfield, Mr. Frederick James
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 882            male  33.0      0      0            349257   7.8958   NaN
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
titanic.to_excel('titanic.xlsx', sheet_name='passengers') ## 데이터프레임을 엑셀로 저장

# %%
titanic = pd.read_excel('titanic.xlsx', sheet_name='passengers', index_col=0)

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ## 데이터 프레임으로 부터 부분 선택

# %%
age = titanic.Age ## 열의 추출, 시리즈 형 반환

# %%
age
# Out:
# PassengerId
# 1      22.0
# 2      38.0
# 3      26.0
# 4      35.0
# 5      35.0
#        ...
# 887    27.0
# 888    19.0
# 889     NaN
# 890    26.0
# 891    32.0
# Name: Age, Length: 891, dtype: float64

# %%
age.shape # 1열이기 때문에 생략됭 있음, 1차원배열의 shape
# Out:
# (891,)

# %%
age_sex = titanic[['Age','Sex']]

# %%
age_sex
# Out:
#               Age     Sex
# PassengerId
# 1            22.0    male
# 2            38.0  female
# 3            26.0  female
# 4            35.0  female
# 5            35.0    male
# ...           ...     ...
# 887          27.0    male
# 888          19.0  female
# 889           NaN  female
# 890          26.0    male
# 891          32.0    male
#
# [891 rows x 2 columns]

# %%
age_sex.shape
# Out:
# (891, 2)

# %% [markdown]
# ## 데이터프레임으로 부터 특정 열을 필터링

# %%
above_35 = titanic[titanic.Age > 35] ## 35세 초과 고객 정보 추출, 논리형 검색 조건 활용

# %%
above_35
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 7                   0       1
# 12                  1       1
# 14                  0       3
# 16                  1       2
# ...               ...     ...
# 866                 1       2
# 872                 1       1
# 874                 0       3
# 880                 1       1
# 886                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 14                                 Andersson, Mr. Anders Johan    male  39.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# ...                                                        ...     ...   ...
# ...

# %%
above_35_name  = titanic[titanic.Age > 35]['Name'] ## 35세 초과 고객 이름 정보만 추출

# %%
above_35_name
# Out:
# PassengerId
# 2      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 7                                McCarthy, Mr. Timothy J
# 12                              Bonnell, Miss. Elizabeth
# 14                           Andersson, Mr. Anders Johan
# 16                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 866                             Bystrom, Mrs. (Karolina)
# 872     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 874                          Vander Cruyssen, Mr. Victor
# 880        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 886                 Rice, Mrs. William (Margaret Norton)
# Name: Name, Length: 217, dtype: object

# %%
class_23 = titanic[(titanic.Pclass == 2) | (titanic.Pclass == 3)]  ## 2,3등칸 고객정보 추출, 조건식의 논리 연결에서 괄호 사용에 주의

# %%
class_23
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 1                   0       3                   Braund, Mr. Owen Harris
# 3                   1       3                    Heikkinen, Miss. Laina
# 5                   0       3                  Allen, Mr. William Henry
# 6                   0       3                          Moran, Mr. James
# 8                   0       3            Palsson, Master. Gosta Leonard
# ...               ...     ...                                       ...
# 885                 0       3                    Sutehall, Mr. Henry Jr
# 886                 0       3      Rice, Mrs. William (Margaret Norton)
# 887                 0       2                     Montvila, Rev. Juozas
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# ...

# %%
age_not_na = titanic[titanic.Age.notna()]  ## notna() 함수 사용

# %%
age_not_na
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 886                 0       3
# 887                 0       2
# 888                 1       1
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ## 데이터프레임에서 특정 열과 행의 데이터만 추출

# %%
above_35_name  = titanic[titanic.Age > 35]['Name'] ## 35세 초과 고객 이름 정보만 추출

# %%
above_35_name
# Out:
# PassengerId
# 2      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 7                                McCarthy, Mr. Timothy J
# 12                              Bonnell, Miss. Elizabeth
# 14                           Andersson, Mr. Anders Johan
# 16                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 866                             Bystrom, Mrs. (Karolina)
# 872     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 874                          Vander Cruyssen, Mr. Victor
# 880        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 886                 Rice, Mrs. William (Margaret Norton)
# Name: Name, Length: 217, dtype: object

# %%
above_35_name_sex  = titanic[titanic.Age > 35][['Name','Sex']]## 35세 초과 고객 이름 정보만 추출

# %%
above_35_name_sex
# Out:
#                                                           Name     Sex
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 7                                      McCarthy, Mr. Timothy J    male
# 12                                    Bonnell, Miss. Elizabeth  female
# 14                                 Andersson, Mr. Anders Johan    male
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female
# ...                                                        ...     ...
# 866                                   Bystrom, Mrs. (Karolina)  female
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female
# 874                                Vander Cruyssen, Mr. Victor    male
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# 886                       Rice, Mrs. William (Margaret Norton)  female
#
# [217 rows x 2 columns]

# %%
## loc() 함수 사용
titanic.loc[titanic.Age > 35, 'Name'] ## 행과열의 이름으로 추출
# Out:
# PassengerId
# 2      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 7                                McCarthy, Mr. Timothy J
# 12                              Bonnell, Miss. Elizabeth
# 14                           Andersson, Mr. Anders Johan
# 16                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 866                             Bystrom, Mrs. (Karolina)
# 872     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 874                          Vander Cruyssen, Mr. Victor
# 880        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 886                 Rice, Mrs. William (Margaret Norton)
# Name: Name, Length: 217, dtype: object

# %%
titanic.loc[titanic.Age > 35, ['Name','Sex']]
# Out:
#                                                           Name     Sex
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 7                                      McCarthy, Mr. Timothy J    male
# 12                                    Bonnell, Miss. Elizabeth  female
# 14                                 Andersson, Mr. Anders Johan    male
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female
# ...                                                        ...     ...
# 866                                   Bystrom, Mrs. (Karolina)  female
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female
# 874                                Vander Cruyssen, Mr. Victor    male
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# 886                       Rice, Mrs. William (Margaret Norton)  female
#
# [217 rows x 2 columns]

# %%
titanic.iloc[9:25, 2:5] ## 인덱스 숫자로 추출
# Out:
#                                                           Name     Sex   Age
# PassengerId
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 11                             Sandstrom, Miss. Marguerite Rut  female   4.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 13                              Saundercock, Mr. William Henry    male  20.0
# 14                                 Andersson, Mr. Anders Johan    male  39.0
# 15                        Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 17                                        Rice, Master. Eugene    male   2.0
# 18                                Williams, Mr. Charles Eugene    male   NaN
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0
# 20                                     Masselmani, Mrs. Fatima  female   NaN
# ...
